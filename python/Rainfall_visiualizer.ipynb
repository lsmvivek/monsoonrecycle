# %%
import numpy as np
import xarray as xr
ds_rain = xr.open_dataset(r"C:\Users\gess-icwar\OneDrive - Indian Institute of Science\Desktop\Project\Matlab Code\Evaporation Files\Clipped Evp\saved_on_disk_2017.nc.",engine="netcdf4")

# Plot at time t
ds_rain.E.isel(time=152).plot()

# %%
ds_rain
